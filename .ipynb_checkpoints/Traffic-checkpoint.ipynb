# %% [markdown]
# ## Traffic

# %%
# %%script echo
# # code to unzip the gtsrb file
# import zipfile as zf
# import os
# files = zf.ZipFile("traffic/gtsrb.zip", 'r') # chnage the path as per
# files.extractall('/traffic/gtsrb')
# files.close()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>
# </div>

# %% [markdown]
# ## Import Packages

# %%
# import packages
import os, cv2, sys
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# define empty list to store the images to be read
images = []
labels = []

# %%
# define input parameters
EPOCHS = 10
IMG_WIDTH = 30
IMG_HEIGHT = 30
NUM_CATEGORIES = 43
TEST_SIZE = 0.4

# %% [markdown]
# ## Read the image files of traffic signs
#
# The `gtsrb` directory will have 43 subdirectories in this dataset. Each numbered subdirectory represents a different category (a different type of road sign). Within each traffic sign’s directory is a collection of images of that type of traffic sign.
#
# The next code block uses the `opencv` library to read the images for each of the subdirectories in the `gtsrb` directory. Then, each image is formatted as a numpy ndarray with dimensions IMG_WIDTH x IMG_HEIGHT x 3. `labels` should be a list of integer labels, representing the categories for each of the corresponding `images`.

# %%
category = 0
while category < NUM_CATEGORIES:
    directory = os.path.dirname(os.getcwd())+os.sep+'gtsrb'+os.sep+str(category)
    print
    for file in os.listdir(directory):
        img = cv2.imread(os.path.join(directory,file))
        img =cv2.resize(img,(IMG_WIDTH, IMG_HEIGHT),interpolation=cv2.INTER_AREA)
        images.append(img)
        labels.append(category)
    category = category + 1

# %%
len(images)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>26640</div>

# %% [markdown]
# Plot some random images to get a visual represenatation of the images

# %%
# random indices of the images for plotting
traffic_signs = [9000,3000,8500,26000]

# fill out the subplots with the random images for which the indices are defined above
for i in range(len(traffic_signs)):
    plt.subplot(1,4,i+1)
    plt.axis('off')
    plt.imshow(images[traffic_signs[i]])

# %% [markdown]
# Conver labels to categorial variable and split the data into training and testing sets

# %%
# convert the 'labels' to categorical variable
labels = tf.keras.utils.to_categorical(labels)

# split data into training and testing sets
x_train,x_test,y_train,y_test = train_test_split(np.array(images),np.array(labels),test_size = TEST_SIZE)

# %%
# option to set printing of mulitple output from a single cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# check shape of train and test data
print('Train and Test data shapes:')
print('x_train: ' + str(x_train.shape))
print('y_train: ' + str(y_train.shape))
print('x_test:  '  + str(x_test.shape))
print('y_test:  '  + str(y_test.shape))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Train and Test data shapes:
# x_train: (15984, 30, 30, 3)
# y_train: (15984, 43)
# x_test:  (10656, 30, 30, 3)
# y_test:  (10656, 43)
# </div>

# %%
# option to reset to single output from a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'last'

# %% [markdown]
# Next, we build a convolution neural network model.

# %% [markdown]
# ## Base Model
#
# Using a sequential model to build a model in keras and use the add function to add layers to the model. The base model will have the following layers.
#
# 1. A Conv2D layer with 32 feature maps, which with a 3x3 kernel and a rectifier activation function.
# 2. Next we define a pooling layer MaxPooling2D layer that takes the max, configured with a pool size of 2×2.
# 3. Next is the Flatten layer that converts the 2D matrix data to a vector that allows the output to be processed by standard fully connected layers.
# 4. Finally, the output layer has 10 neurons for the 10 classes and a softmax activation function to output probability-like predictions for each label.

# %%
# Build the base CNN model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(NUM_CATEGORIES,activation='softmax'))

# %%
# check model summary
model.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Model: &quot;sequential&quot;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 43)                269739
# =================================================================
# Total params: 270,635
# Trainable params: 270,635
# Non-trainable params: 0
# _________________________________________________________________
# </div>

# %%
# compile the model
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

history = model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs=EPOCHS)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Train on 15984 samples, validate on 10656 samples
# Epoch 1/10
# 15984/15984 [==============================] - 9s 589us/sample - loss: 9.4269 - accuracy: 0.6672 - val_loss: 0.6395 - val_accuracy: 0.8546
# Epoch 2/10
# 15984/15984 [==============================] - 8s 513us/sample - loss: 0.3299 - accuracy: 0.9237 - val_loss: 0.5215 - val_accuracy: 0.8970
# Epoch 3/10
# 15984/15984 [==============================] - 8s 504us/sample - loss: 0.1957 - accuracy: 0.9510 - val_loss: 0.4697 - val_accuracy: 0.9166
# Epoch 4/10
# 15984/15984 [==============================] - 8s 520us/sample - loss: 0.1760 - accuracy: 0.9591 - val_loss: 0.4902 - val_accuracy: 0.9116
# Epoch 5/10
# 15984/15984 [==============================] - 8s 470us/sample - loss: 0.2224 - accuracy: 0.9486 - val_loss: 0.4837 - val_accuracy: 0.9281
# Epoch 6/10
# 15984/15984 [==============================] - 8s 482us/sample - loss: 0.1187 - accuracy: 0.9732 - val_loss: 0.4517 - val_accuracy: 0.9367
# Epoch 7/10
# 15984/15984 [==============================] - 8s 475us/sample - loss: 0.1409 - accuracy: 0.9692 - val_loss: 0.4735 - val_accuracy: 0.9367
# Epoch 8/10
# 15984/15984 [==============================] - 8s 490us/sample - loss: 0.1373 - accuracy: 0.9726 - val_loss: 0.6472 - val_accuracy: 0.9104
# Epoch 9/10
# 15984/15984 [==============================] - 8s 495us/sample - loss: 0.1702 - accuracy: 0.9666 - val_loss: 0.6270 - val_accuracy: 0.9334
# Epoch 10/10
# 15984/15984 [==============================] - 8s 492us/sample - loss: 0.1030 - accuracy: 0.9789 - val_loss: 0.8347 - val_accuracy: 0.9231
# </div>

# %%
# Plot training and validation loss over epochs
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 1
#
# In this iteration, we add a `Dropout layer` configured to randomly exclude 50% of neurons in the layer in order to reduce overfitting.

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(NUM_CATEGORIES,activation='softmax'))

# %%
# check model summary
model.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Model: &quot;sequential_1&quot;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                269739
# =================================================================
# Total params: 270,635
# Trainable params: 270,635
# Non-trainable params: 0
# _________________________________________________________________
# </div>

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

history = model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs=EPOCHS)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Train on 15984 samples, validate on 10656 samples
# Epoch 1/10
# 15984/15984 [==============================] - 10s 626us/sample - loss: 6.4974 - accuracy: 0.4568 - val_loss: 0.9924 - val_accuracy: 0.7543
# Epoch 2/10
# 15984/15984 [==============================] - 9s 594us/sample - loss: 1.0928 - accuracy: 0.7285 - val_loss: 0.7098 - val_accuracy: 0.8394
# Epoch 3/10
# 15984/15984 [==============================] - 9s 583us/sample - loss: 0.8597 - accuracy: 0.7836 - val_loss: 0.6044 - val_accuracy: 0.8636
# Epoch 4/10
# 15984/15984 [==============================] - 10s 597us/sample - loss: 0.7263 - accuracy: 0.8176 - val_loss: 0.5043 - val_accuracy: 0.8874
# Epoch 5/10
# 15984/15984 [==============================] - 10s 610us/sample - loss: 0.6948 - accuracy: 0.8302 - val_loss: 0.4888 - val_accuracy: 0.8911
# Epoch 6/10
# 15984/15984 [==============================] - 10s 598us/sample - loss: 0.6844 - accuracy: 0.8417 - val_loss: 0.4739 - val_accuracy: 0.8951
# Epoch 7/10
# 15984/15984 [==============================] - 9s 592us/sample - loss: 0.6184 - accuracy: 0.8501 - val_loss: 0.4510 - val_accuracy: 0.8998
# Epoch 8/10
# 15984/15984 [==============================] - 10s 599us/sample - loss: 0.5869 - accuracy: 0.8615 - val_loss: 0.4548 - val_accuracy: 0.9077
# Epoch 9/10
# 15984/15984 [==============================] - 9s 585us/sample - loss: 0.6458 - accuracy: 0.8515 - val_loss: 0.4975 - val_accuracy: 0.8912
# Epoch 10/10
# 15984/15984 [==============================] - 9s 578us/sample - loss: 0.5741 - accuracy: 0.8696 - val_loss: 0.4411 - val_accuracy: 0.9170
# </div>

# %%
# Plot training and validation loss over epochs
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 2
#
# In this iteration, we add another Conv2D layer with 64 feature maps. The higher the number of filters, the higher the number of abstractions that your Network is able to extract from image data. The reason why the number of filters is generally ascending is that at the input layer the Network receives raw pixel data. Raw data are always noisy, and this is especially true for image data.
#
# Because of this, we let CNNs extract first some relevant information from noisy, "dirty" raw pixel data. Once the useful features have been extracted, then we make the CNN elaborate more complex abstractions on it.

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(NUM_CATEGORIES,activation='softmax'))

# %%
# check model summary
model.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Model: &quot;sequential_2&quot;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2304)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 43)                99115
# =================================================================
# Total params: 118,507
# Trainable params: 118,507
# Non-trainable params: 0
# _________________________________________________________________
# </div>

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

history = model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs=EPOCHS)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Train on 15984 samples, validate on 10656 samples
# Epoch 1/10
# 15984/15984 [==============================] - 13s 798us/sample - loss: 3.8084 - accuracy: 0.2673 - val_loss: 1.7363 - val_accuracy: 0.5663
# Epoch 2/10
# 15984/15984 [==============================] - 14s 852us/sample - loss: 1.5847 - accuracy: 0.5399 - val_loss: 0.8308 - val_accuracy: 0.7560
# Epoch 3/10
# 15984/15984 [==============================] - 13s 813us/sample - loss: 1.0557 - accuracy: 0.6883 - val_loss: 0.5691 - val_accuracy: 0.8463
# Epoch 4/10
# 15984/15984 [==============================] - 13s 833us/sample - loss: 0.7639 - accuracy: 0.7789 - val_loss: 0.3262 - val_accuracy: 0.9177
# Epoch 5/10
# 15984/15984 [==============================] - 13s 809us/sample - loss: 0.5960 - accuracy: 0.8305 - val_loss: 0.2390 - val_accuracy: 0.9407
# Epoch 6/10
# 15984/15984 [==============================] - 13s 822us/sample - loss: 0.4848 - accuracy: 0.8609 - val_loss: 0.1789 - val_accuracy: 0.9531
# Epoch 7/10
# 15984/15984 [==============================] - 13s 832us/sample - loss: 0.4037 - accuracy: 0.8873 - val_loss: 0.1620 - val_accuracy: 0.9581
# Epoch 8/10
# 15984/15984 [==============================] - 13s 830us/sample - loss: 0.3533 - accuracy: 0.9005 - val_loss: 0.1522 - val_accuracy: 0.9638
# Epoch 9/10
# 15984/15984 [==============================] - 13s 816us/sample - loss: 0.3079 - accuracy: 0.9128 - val_loss: 0.1469 - val_accuracy: 0.9623
# Epoch 10/10
# 15984/15984 [==============================] - 13s 800us/sample - loss: 0.2912 - accuracy: 0.9195 - val_loss: 0.1124 - val_accuracy: 0.9729
# </div>

# %%
# Plot training and validation loss over epochs
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 3
#
# Add another Conv2D layer with 128 feature maps

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(NUM_CATEGORIES,activation='softmax'))

# %%
# check model 
model.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Model: &quot;sequential_3&quot;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                22059
# =================================================================
# Total params: 115,307
# Trainable params: 115,307
# Non-trainable params: 0
# _________________________________________________________________
# </div>

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

history = model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs=EPOCHS)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Train on 15984 samples, validate on 10656 samples
# Epoch 1/10
# 15984/15984 [==============================] - 15s 947us/sample - loss: 2.9145 - accuracy: 0.3343 - val_loss: 1.0704 - val_accuracy: 0.7293
# Epoch 2/10
# 15984/15984 [==============================] - 15s 912us/sample - loss: 0.9699 - accuracy: 0.7279 - val_loss: 0.3828 - val_accuracy: 0.9040
# Epoch 3/10
# 15984/15984 [==============================] - 14s 897us/sample - loss: 0.5176 - accuracy: 0.8579 - val_loss: 0.2354 - val_accuracy: 0.9435
# Epoch 4/10
# 15984/15984 [==============================] - 15s 921us/sample - loss: 0.3907 - accuracy: 0.8946 - val_loss: 0.2233 - val_accuracy: 0.9494
# Epoch 5/10
# 15984/15984 [==============================] - 15s 909us/sample - loss: 0.3141 - accuracy: 0.9115 - val_loss: 0.1389 - val_accuracy: 0.9666
# Epoch 6/10
# 15984/15984 [==============================] - 14s 866us/sample - loss: 0.2593 - accuracy: 0.9293 - val_loss: 0.1217 - val_accuracy: 0.9718
# Epoch 7/10
# 15984/15984 [==============================] - 14s 850us/sample - loss: 0.2401 - accuracy: 0.9330 - val_loss: 0.1507 - val_accuracy: 0.9589
# Epoch 8/10
# 15984/15984 [==============================] - 15s 919us/sample - loss: 0.2121 - accuracy: 0.9410 - val_loss: 0.1319 - val_accuracy: 0.9654
# Epoch 9/10
# 15984/15984 [==============================] - 14s 893us/sample - loss: 0.2196 - accuracy: 0.9410 - val_loss: 0.1301 - val_accuracy: 0.9697
# Epoch 10/10
# 15984/15984 [==============================] - 14s 897us/sample - loss: 0.2111 - accuracy: 0.9451 - val_loss: 0.1184 - val_accuracy: 0.9725
# </div>

# %%
# Plot training and validation loss over epochs
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Model 4
#
# Another Dense layer

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(64,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Conv2D(128,(3,3),activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(128,activation='relu'))
model.add(tf.keras.layers.Dense(NUM_CATEGORIES,activation='softmax'))

# %%
model.summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Model: &quot;sequential_4&quot;
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 12, 12, 64)        18496
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                5547
# =================================================================
# Total params: 164,459
# Trainable params: 164,459
# Non-trainable params: 0
# _________________________________________________________________
# </div>

# %%
model.compile(optimizer='adam',
             loss='categorical_crossentropy',
             metrics = ['accuracy'])

history = model.fit(x_train,y_train,validation_data=(x_test, y_test),epochs=EPOCHS)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class='ansiout'>Train on 15984 samples, validate on 10656 samples
# Epoch 1/10
# 15984/15984 [==============================] - 15s 949us/sample - loss: 2.5074 - accuracy: 0.3886 - val_loss: 0.8529 - val_accuracy: 0.7568
# Epoch 2/10
# 15984/15984 [==============================] - 15s 969us/sample - loss: 0.8028 - accuracy: 0.7703 - val_loss: 0.3113 - val_accuracy: 0.9240
# Epoch 3/10
# 15984/15984 [==============================] - 15s 920us/sample - loss: 0.4288 - accuracy: 0.8766 - val_loss: 0.1815 - val_accuracy: 0.9495
# Epoch 4/10
# 15984/15984 [==============================] - 14s 900us/sample - loss: 0.3152 - accuracy: 0.9112 - val_loss: 0.1008 - val_accuracy: 0.9739
# Epoch 5/10
# 15984/15984 [==============================] - 15s 925us/sample - loss: 0.2489 - accuracy: 0.9299 - val_loss: 0.0996 - val_accuracy: 0.9734
# Epoch 6/10
# 15984/15984 [==============================] - 14s 907us/sample - loss: 0.2289 - accuracy: 0.9360 - val_loss: 0.0923 - val_accuracy: 0.9746
# Epoch 7/10
# 15984/15984 [==============================] - 15s 919us/sample - loss: 0.2111 - accuracy: 0.9406 - val_loss: 0.0760 - val_accuracy: 0.9784
# Epoch 8/10
# 15984/15984 [==============================] - 14s 904us/sample - loss: 0.2002 - accuracy: 0.9470 - val_loss: 0.0865 - val_accuracy: 0.9764
# Epoch 9/10
# 15984/15984 [==============================] - 14s 875us/sample - loss: 0.1650 - accuracy: 0.9546 - val_loss: 0.0915 - val_accuracy: 0.9756
# Epoch 10/10
# 15984/15984 [==============================] - 14s 887us/sample - loss: 0.1603 - accuracy: 0.9558 - val_loss: 0.0598 - val_accuracy: 0.9834
# </div>

# %%
# Plot training and validation loss over epochs
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# |Iteration| Model Components | Training Accuracy | Validation Accuracy
# | --------- |:----------- |----------|------------|
# | <p style='text-align: left;'>Base | <p style='text-align: left;'>Conv2D, MaxPooling, Flatten, Dense| 97.89%| 92.28%|
# | <p style='text-align: left;'>Model 1 |<p style='text-align: left;'>Add a Dropout Layer to the base model| 86.96%|91.70%|
# | <p style='text-align: left;'>Model 2 |<p style='text-align: left;'>Add another Conv2D layer withh 64 feature maps | 91.95%|97.29%|
# | <p style='text-align: left;'>Model 3 | Add another Conv2D layer with 128 feature maps | 94.51%| 97.25%|
# | <p style='text-align: left;'>Model 4 | Add a Dense layer with 128 feature maps | 95.58%| 98.34%|

# %% [markdown]
# ### Conclusion
#
# 1. The base model performs wells on the training dataset. However, this seems to be a case of overfitting as the model does not perform well on the test data.
#
# 2. Adding a `Dropout` layer does not improve accuracy suggesting further layers need to be added to enhance model accuracy.
#
# 3. Adding another `Conv2D` layer improves the training model accuracy from the pevious model and generalizes pretty well on the testing data.
#
# 4. Adding one more `Conv2D` layer improves the training accuracy but does not improve the testing accuracy any further.
#
# 5. By further adding a `Dense` layer improves the training accuracy as well as fits the best on the testing data.
